# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import rcParams

# %% [markdown]
# ## Loading the data

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
msft.history(period="max")
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# 1986-03-20    0.06    0.06    0.06    0.06    58435200        0.0
# 1986-03-21    0.06    0.06    0.06    0.06    59990400        0.0
# 1986-03-24    0.06    0.06    0.06    0.06    65289600        0.0
# 1986-03-25    0.06    0.06    0.06    0.06    32083200        0.0
# 1986-03-26    0.06    0.06    0.06    0.06    22752000        0.0
# 1986-03-27    0.06    0.06    0.06    0.06    16848000        0.0
# 1986-03-31    0.06    0.06    0.06    0.06    12873600        0.0
# 1986-04-01    0.06    0.06    0.06    0.06    11088000        0.0
# ...

# %%
Stock=msft.history(period="max")

# %% [markdown]
# ## Data Preprocessing and cleaning

# %%
Stock.head().append(Stock.tail())
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# 2020-06-26  199.73  199.89  194.88  196.33    54675800        0.0
# 2020-06-29  195.78  198.53  193.55  198.44    26701600        0.0
# 2020-06-30  197.88  204.40  197.74  203.51    34310300        0.0
# 2020-07-01  203.14  206.35  201.77  204.70    32061200        0.0
# 2020-07-02  205.68  208.02  205.00  206.26    29315800        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# 2020-06-26           0.0
# 2020-06-29           0.0
# ...

# %%
Stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8648 entries, 1986-03-13 to 2020-07-02
# Data columns (total 7 columns):
# Open            8648 non-null float64
# High            8648 non-null float64
# Low             8648 non-null float64
# Close           8648 non-null float64
# Volume          8648 non-null int64
# Dividends       8648 non-null float64
# Stock Splits    8648 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 540.5 KB

# %%
Stock.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8648.000000  8648.000000  8648.000000  8648.000000  8.648000e+03
# mean     25.419572    25.687429    25.146943    25.426774  6.023024e+07
# std      33.080451    33.410215    32.732752    33.096182  3.874776e+07
# min       0.060000     0.060000     0.060000     0.060000  2.304000e+06
# 25%       2.267500     2.300000     2.247500     2.270000  3.645112e+07
# 50%      18.510000    18.745000    18.280000    18.495000  5.335630e+07
# 75%      25.860000    26.112500    25.535000    25.810000  7.391490e+07
# max     205.680000   208.020000   205.000000   206.260000  1.031789e+09
#
#          Dividends  Stock Splits
# count  8648.000000   8648.000000
# mean      0.002155      0.001966
# std       0.040793      0.061275
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       3.080000      2.000000

# %%
Stock.shape
# Out:
# (8648, 7)

# %%
Stock.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
Stock.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
Stock.dropna(inplace=True)

# %% [markdown]
# ## Data Exploration and visualisation

# %%
plt.hist(Stock.Close)
# Out:
# (array([5124., 2199.,  505.,  186.,  178.,  164.,  135.,   72.,   60.,
#           25.]),
#  array([6.0000e-02, 2.0680e+01, 4.1300e+01, 6.1920e+01, 8.2540e+01,
#         1.0316e+02, 1.2378e+02, 1.4440e+02, 1.6502e+02, 1.8564e+02,
#         2.0626e+02]),
#  <a list of 10 Patch objects>)

# %%
log_close=np.log(Stock['Close'])
Stock['log_close']=log_close
Stock
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# 1986-03-20    0.06    0.06    0.06    0.06    58435200        0.0
# 1986-03-21    0.06    0.06    0.06    0.06    59990400        0.0
# 1986-03-24    0.06    0.06    0.06    0.06    65289600        0.0
# 1986-03-25    0.06    0.06    0.06    0.06    32083200        0.0
# 1986-03-26    0.06    0.06    0.06    0.06    22752000        0.0
# 1986-03-27    0.06    0.06    0.06    0.06    16848000        0.0
# 1986-03-31    0.06    0.06    0.06    0.06    12873600        0.0
# 1986-04-01    0.06    0.06    0.06    0.06    11088000        0.0
# ...

# %%
plt.hist(Stock.log_close)
# Out:
# (array([ 212.,  674.,  335.,  390.,  765.,  415., 1267., 3233.,  798.,
#          559.]),
#  array([-2.81341072, -1.99915589, -1.18490107, -0.37064625,  0.44360857,
#          1.2578634 ,  2.07211822,  2.88637304,  3.70062786,  4.51488269,
#          5.32913751]),
#  <a list of 10 Patch objects>)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3))
ax1.scatter(Stock['Open'],Stock['log_close'])
ax1.set_title('Log Close and Open')
ax2.scatter(Stock['High'],Stock['log_close'])
ax2.set_title('Log Close and High')
ax3.scatter(Stock['Low'],Stock['log_close'])
ax3.set_title('Log Close and Low')

plt.show()

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize =(15,3))
ax1.scatter(Stock['Volume'],Stock['log_close'])
ax1.set_title('Log Close and Volume')
ax2.scatter(Stock['Dividends'],Stock['log_close'])
ax2.set_title('Log Close and Dividends')
ax3.scatter(Stock['Low'],Stock['High'])
ax3.set_title('Low and High')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(Stock["Open"],Stock["High"])
plt.show()

# %%
plt.scatter(Stock["Volume"],Stock["Dividends"])
plt.show()

# %%
plt.scatter(Stock["Open"],Stock["Volume"])
plt.show()

# %%
plt.scatter(Stock["Dividends"],Stock["High"])
plt.show()

# %%
plt.hist(Stock["Open"])
plt.show()

# %%
plt.hist(Stock["Low"])
plt.show()

# %%
plt.hist(Stock["High"])
plt.show()

# %%
plt.hist(Stock["Dividends"])
plt.show()

# %%
plt.hist(Stock["Volume"])
plt.show()

# %%
plt.hist(Stock["Stock Splits"])
plt.show()

# %%
np.corrcoef(Stock['Low'],Stock['High'])
# Out:
# array([[1.        , 0.99982802],
#        [0.99982802, 1.        ]])

# %%
from datetime import datetime

# %%
Price=Stock.reset_index(level='Date')

# %%
Price.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'log_close'],
#       dtype='object')

# %%
Price.shape
# Out:
# (8648, 9)

# %% [markdown]
# ## LSTM Model

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(Price['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD ($)',fontsize=18)
plt.show()

# %%
data = Price.filter(['Close'])

# %%
dataset = data.values

# %%
import math
training_data_len = math.ceil( len(dataset) *.8)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) 
scaled_data = scaler.fit_transform(dataset)

# %%
train_data = scaled_data[0:training_data_len  , : ]

# %%
x_train=[]
y_train = []
for i in range(60,len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])

# %%
import numpy as np
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
##Reshape input to be[sample,time steps,features]which is required for LSTM
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
##Create stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=1, epochs=1)
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# Train on 6859 samples
# 6859/6859 [==============================] - 364s 53ms/sample - loss: 3.6155e-05
# Train on 6859 samples
# 6859/6859 [==============================] - 339s 49ms/sample - loss: 1.4373e-05

# %%
test_data = scaled_data[training_data_len - 60: , : ]

# %%
x_test = []
y_test =  dataset[training_data_len : , : ] #Get all of the rows from index 1603 to the rest and all of the columns (in this case it's only column 'Close'), so 2003 - 1603 = 400 rows of data
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %%
x_test = np.array(x_test)

# %%
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
predictions = model.predict(x_test) 
predictions = scaler.inverse_transform(predictions)

# %%
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# 3.5437914336105654

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()

# %%
valid
# Out:
#        Close  Predictions
# 6919   27.26    28.284374
# 6920   27.94    28.304335
# 6921   29.97    28.929625
# 6922   29.45    30.904636
# 6923   28.69    30.757938
# 6924   28.48    29.979256
# 6925   28.94    29.638050
# 6926   28.81    30.013937
# 6927   27.50    29.967642
# 6928   26.91    28.744368
# 6929   26.94    27.984680
# 6930   26.87    27.905312
# 6931   27.31    27.853279
# 6932   27.94    28.258312
# 6933   28.24    28.915392
# 6934   28.19    29.304081
# 6935   28.49    29.315357
# 6936   28.29    29.584829
# 6937   28.40    29.448799
# 6938   28.74    29.520409
# 6939   29.01    29.845997
# 6940   28.28    30.146917
# 6941   28.24    29.515530
# 6942   27.99    29.354008
# 6943   28.04    29.104227
# 6944   28.26    29.109802
# 6945   28.70    29.317924
# 6946   28.70    29.758789
# 6947   28.96    29.830843
# 6948   29.26    30.070698
# ...      ...          ...
# 8618  183.43   190.349457
# 8619  183.51   188.200882
# 8620  181.57   187.979324
# ...
